# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import pprint
import json
from time import sleep
from datetime import date

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
# pip install citipy
from citipy import citipy

# Output File location
output_folder = "output_data"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Think I can delete this:
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
max_rows = 620 # Allows me to control # of API calls during testing to make it faster to iterate

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Create a dataframe and populate w the lat/lon
df = pd.DataFrame(lat_lngs, columns = ['Latitude', 'Longitude']) 

# Add the new columns you later need to get:
df["City"] = ""
df["Country"] = ""
df["Date"] = date.today()
df["Cloudiness"] = np.NaN
df["Humidity"] = np.NaN
df["Max Temp"] = np.NaN
df["Wind Speed"] = np.NaN

curr_rows = len(df)
print(f'There are {curr_rows} coordinates in the dataframe')

if curr_rows > max_rows:
    print(f"... that's more than the max of {max_rows} - culling to only be {max_rows}")
    df = df.head(max_rows)
    curr_rows = len(df)
    print(f'There are now {curr_rows} coordinates in the dataframe')
    
df.head()
# Out:
# There are 1500 coordinates in the dataframe
# ... that's more than the max of 620 - culling to only be 620
# There are now 620 coordinates in the dataframe
#     Latitude  Longitude City Country        Date  Cloudiness  Humidity  \
# 0  22.233088 -49.676308               2020-01-23         NaN       NaN
# 1 -70.151047  26.986246               2020-01-23         NaN       NaN
# 2 -75.898007   5.550883               2020-01-23         NaN       NaN
# 3 -82.451657 -60.138620               2020-01-23         NaN       NaN
# 4  83.501309 -56.554683               2020-01-23         NaN       NaN
#
#    Max Temp  Wind Speed
# 0       NaN         NaN
# 1       NaN         NaN
# 2       NaN         NaN
# 3       NaN         NaN
# 4       NaN         NaN

# %%
# Loop through the lat/lng and get the closest city (using citipy)
for index, row in df.iterrows():
    city = citipy.nearest_city(row["Latitude"], row["Longitude"])
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        #cities.append(city)
        df.loc[index, "City"] = city.city_name
        df.loc[index, "Country"] = city.country_code
        
df.head()
# Out:
#     Latitude  Longitude          City Country        Date  Cloudiness  \
# 0  22.233088 -49.676308    codrington      ag  2020-01-23         NaN
# 1 -70.151047  26.986246  kruisfontein      za  2020-01-23         NaN
# 2 -75.898007   5.550883      hermanus      za  2020-01-23         NaN
# 3 -82.451657 -60.138620       ushuaia      ar  2020-01-23         NaN
# 4  83.501309 -56.554683     upernavik      gl  2020-01-23         NaN
#
#    Humidity  Max Temp  Wind Speed
# 0       NaN       NaN         NaN
# 1       NaN       NaN         NaN
# 2       NaN       NaN         NaN
# 3       NaN       NaN         NaN
# 4       NaN       NaN         NaN

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information for https://openweathermap.org/current current weather:
base_url = "https://api.openweathermap.org/data/2.5/weather?"

# set up a parameters dictionary
params = {
    "appid": weather_api_key,
    "units": "imperial" # from api doc: "For temperature in Fahrenheit use units=imperial"
}

# base url
print('Beginning Data Retrieval')
print('----------------------------')

total_rows  = len(df)
total_rows_processed = 0
ctr = 0
batch = 1
rows_in_batch = 47
rows_processed_in_batch = 0

# Loop through datafram RBAR:
for index, row in df.iterrows():
    ctr += 1
    rows_processed_in_batch += 1
    total_rows_processed += 1
    
    # Sleep after every 47 calls:
    if rows_processed_in_batch >= rows_in_batch:
        batch += 1
        rows_processed_in_batch = 0
        print('')
        print('------------------------------')
        print(f'   {total_rows_processed} rows processed - {total_rows - total_rows_processed} remain')
        print('------------------------------')
        print('')
        sleep(1.01) # Time in seconds
           
    searchTerm = f'{row["City"]}, {row["Country"]}'
    params['q'] = searchTerm
    print(f'Processing record {ctr} of Set {batch} | {searchTerm}')
    
    # make request
    weather = requests.get(base_url, params=params)
    # print(weather.url)
    
    # convert to json
    weather_json = weather.json()
    #print(json.dumps(weather_json, indent=4))
    #break
    # Get the data
    
    # from docs: "For temperature in Fahrenheit use units=imperial"
    try:
        df.loc[index, "Cloudiness"] = f'{weather_json["clouds"]["all"]}'
        df.loc[index, "Humidity"] = f'{weather_json["main"]["humidity"]}'
        df.loc[index, "Max Temp"] = f'{weather_json["main"]["temp_max"]}'
        df.loc[index, "Wind Speed"] = f'{weather_json["wind"]["speed"]}'
    except:
        print("   error - one of the data points was not found for this city/country")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing record 1 of Set 1 | codrington, ag
#    error - one of the data points was not found for this city/country
# Processing record 2 of Set 1 | kruisfontein, za
# Processing record 3 of Set 1 | hermanus, za
# Processing record 4 of Set 1 | ushuaia, ar
# Processing record 5 of Set 1 | upernavik, gl
# Processing record 6 of Set 1 | belushya guba, ru
#    error - one of the data points was not found for this city/country
# Processing record 7 of Set 1 | rikitea, pf
# Processing record 8 of Set 1 | taolanaro, mg
#    error - one of the data points was not found for this city/country
# Processing record 9 of Set 1 | rikitea, pf
# Processing record 10 of Set 1 | mataura, pf
#    error - one of the data points was not found for this city/country
# Processing record 11 of Set 1 | rikitea, pf
# Processing record 12 of Set 1 | chagda, ru
#    error - one of the data points was not found for this city/country
# Processing record 13 of Set 1 | itarema, br
# Processing record 14 of Set 1 | lebu, cl
# Processing record 15 of Set 1 | saskylakh, ru
# Processing record 16 of Set 1 | jiutai, cn
# Processing record 17 of Set 1 | jamestown, sh
# Processing record 18 of Set 1 | virginia beach, us
# Processing record 19 of Set 1 | jamestown, sh
# Processing record 20 of Set 1 | altay, cn
# Processing record 21 of Set 1 | rio tercero, ar
# Processing record 22 of Set 1 | sri aman, my
# Processing record 23 of Set 1 | sheridan, us
# Processing record 24 of Set 1 | witu, ke
# Processing record 25 of Set 1 | arraial do cabo, br
# Processing record 26 of Set 1 | atuona, pf
# Processing record 27 of Set 1 | airai, pw
#    error - one of the data points was not found for this city/country
# Processing record 28 of Set 1 | severo-kurilsk, ru
# Processing record 29 of Set 1 | saint george, bm
# Processing record 30 of Set 1 | talnakh, ru
# Processing record 31 of Set 1 | mrirt, ma
#    error - one of the data points was not found for this city/country
# Processing record 32 of Set 1 | hervey bay, au
# Processing record 33 of Set 1 | barrow, us
# Processing record 34 of Set 1 | almenevo, ru
#    error - one of the data points was not found for this city/country
# Processing record 35 of Set 1 | zhezkazgan, kz
# Processing record 36 of Set 1 | illoqqortoormiut, gl
#    error - one of the data points was not found for this city/country
# Processing record 37 of Set 1 | mataura, pf
#    error - one of the data points was not found for this city/country
# Processing record 38 of Set 1 | cockburn town, bs
# Processing record 39 of Set 1 | fayaoue, nc
# Processing record 40 of Set 1 | jamestown, sh
# Processing record 41 of Set 1 | mahebourg, mu
# Processing record 42 of Set 1 | bluff, nz
# Processing record 43 of Set 1 | coos bay, us
# Processing record 44 of Set 1 | malanje, ao
# Processing record 45 of Set 1 | klaksvik, fo
# Processing record 46 of Set 1 | aitape, pg
#
# ------------------------------
#    47 rows processed - 573 remain
# ------------------------------
#
# Processing record 47 of Set 2 | rikitea, pf
# Processing record 48 of Set 2 | abu samrah, qa
#    error - one of the data points was not found for this city/country
# Processing record 49 of Set 2 | paamiut, gl
# Processing record 50 of Set 2 | hambantota, lk
# Processing record 51 of Set 2 | mataura, pf
#    error - one of the data points was not found for this city/country
# Processing record 52 of Set 2 | puerto ayora, ec
# Processing record 53 of Set 2 | santiago, ph
# Processing record 54 of Set 2 | busselton, au
# Processing record 55 of Set 2 | illoqqortoormiut, gl
#    error - one of the data points was not found for this city/country
# Processing record 56 of Set 2 | nassau, bs
# Processing record 57 of Set 2 | chuy, uy
# Processing record 58 of Set 2 | kainantu, pg
# Processing record 59 of Set 2 | severnyy, ru
# Processing record 60 of Set 2 | ushibuka, jp
# Processing record 61 of Set 2 | geraldton, au
# Processing record 62 of Set 2 | avarua, ck
# Processing record 63 of Set 2 | dikson, ru
# Processing record 64 of Set 2 | jamestown, sh
# Processing record 65 of Set 2 | carballo, es
# Processing record 66 of Set 2 | punta arenas, cl
# Processing record 67 of Set 2 | la asuncion, ve
# Processing record 68 of Set 2 | hobart, au
# Processing record 69 of Set 2 | hobart, au
# Processing record 70 of Set 2 | erhlin, tw
#    error - one of the data points was not found for this city/country
# Processing record 71 of Set 2 | husavik, is
# Processing record 72 of Set 2 | jamestown, sh
# Processing record 73 of Set 2 | atuona, pf
# Processing record 74 of Set 2 | kindu, cd
# Processing record 75 of Set 2 | rikitea, pf
# Processing record 76 of Set 2 | belushya guba, ru
#    error - one of the data points was not found for this city/country
# Processing record 77 of Set 2 | yarada, in
# Processing record 78 of Set 2 | barahona, do
# Processing record 79 of Set 2 | lorengau, pg
# Processing record 80 of Set 2 | cherskiy, ru
# Processing record 81 of Set 2 | albany, au
# Processing record 82 of Set 2 | cidreira, br
# Processing record 83 of Set 2 | rikitea, pf
# Processing record 84 of Set 2 | bethel, us
# Processing record 85 of Set 2 | alberton, ca
# Processing record 86 of Set 2 | hobart, au
# Processing record 87 of Set 2 | atuona, pf
# Processing record 88 of Set 2 | auki, sb
# Processing record 89 of Set 2 | bluff, nz
# Processing record 90 of Set 2 | marcona, pe
#    error - one of the data points was not found for this city/country
# Processing record 91 of Set 2 | clyde river, ca
# Processing record 92 of Set 2 | torbay, ca
# Processing record 93 of Set 2 | adet, et
#
# ------------------------------
#    94 rows processed - 526 remain
# ------------------------------
#
# Processing record 94 of Set 3 | mys shmidta, ru
#    error - one of the data points was not found for this city/country
# Processing record 95 of Set 3 | jamestown, sh
# Processing record 96 of Set 3 | alyangula, au
# Processing record 97 of Set 3 | muyezerskiy, ru
# Processing record 98 of Set 3 | lujan, ar
# Processing record 99 of Set 3 | hualmay, pe
# Processing record 100 of Set 3 | langham, ca
# Processing record 101 of Set 3 | araouane, ml
# Processing record 102 of Set 3 | airai, pw
#    error - one of the data points was not found for this city/country
# Processing record 103 of Set 3 | vaini, to
# Processing record 104 of Set 3 | busselton, au
# Processing record 105 of Set 3 | albany, au
# Processing record 106 of Set 3 | sangar, ru
# Processing record 107 of Set 3 | port elizabeth, za
# Processing record 108 of Set 3 | mount isa, au
# Processing record 109 of Set 3 | ushuaia, ar
# Processing record 110 of Set 3 | sorland, no
# Processing record 111 of Set 3 | ushuaia, ar
# Processing record 112 of Set 3 | rikitea, pf
# Processing record 113 of Set 3 | saint-philippe, re
# Processing record 114 of Set 3 | comodoro rivadavia, ar
# Processing record 115 of Set 3 | chuy, uy
# Processing record 116 of Set 3 | sumbe, ao
# Processing record 117 of Set 3 | hermanus, za
# Processing record 118 of Set 3 | eyrarbakki, is
# Processing record 119 of Set 3 | mataura, pf
#    error - one of the data points was not found for this city/country
# Processing record 120 of Set 3 | daru, pg
# Processing record 121 of Set 3 | mattru, sl
# Processing record 122 of Set 3 | busselton, au
# Processing record 123 of Set 3 | carnarvon, au
# Processing record 124 of Set 3 | port alfred, za
# Processing record 125 of Set 3 | hobart, au
# Processing record 126 of Set 3 | bonthe, sl
# Processing record 127 of Set 3 | cape town, za
# Processing record 128 of Set 3 | khatanga, ru
# Processing record 129 of Set 3 | san jeronimo, mx
# Processing record 130 of Set 3 | vaini, to
# Processing record 131 of Set 3 | aleksandrov gay, ru
# Processing record 132 of Set 3 | cape town, za
# Processing record 133 of Set 3 | ulsteinvik, no
# Processing record 134 of Set 3 | bredasdorp, za
# Processing record 135 of Set 3 | manokwari, id
# Processing record 136 of Set 3 | mar del plata, ar
# Processing record 137 of Set 3 | albany, us
# Processing record 138 of Set 3 | viedma, ar
# Processing record 139 of Set 3 | siklos, hu
# Processing record 140 of Set 3 | itupiranga, br
#
# ------------------------------
#    141 rows processed - 479 remain
# ------------------------------
#
# Processing record 141 of Set 4 | rikitea, pf
# Processing record 142 of Set 4 | rikitea, pf
# Processing record 143 of Set 4 | busselton, au
# Processing record 144 of Set 4 | shuangyang, cn
# Processing record 145 of Set 4 | bluff, nz
# Processing record 146 of Set 4 | shache, cn
# Processing record 147 of Set 4 | punta arenas, cl
# Processing record 148 of Set 4 | rikitea, pf
# Processing record 149 of Set 4 | bluff, nz
# Processing record 150 of Set 4 | pevek, ru
# Processing record 151 of Set 4 | tuktoyaktuk, ca
# Processing record 152 of Set 4 | georgetown, sh
# Processing record 153 of Set 4 | kununurra, au
# Processing record 154 of Set 4 | lagoa, pt
# Processing record 155 of Set 4 | busselton, au
# Processing record 156 of Set 4 | saldanha, za
# Processing record 157 of Set 4 | mataura, pf
#    error - one of the data points was not found for this city/country
# Processing record 158 of Set 4 | esperance, au
# Processing record 159 of Set 4 | faanui, pf
# Processing record 160 of Set 4 | torbay, ca
# Processing record 161 of Set 4 | petropavlovsk-kamchatskiy, ru
# Processing record 162 of Set 4 | chivilcoy, ar
# Processing record 163 of Set 4 | taltal, cl
# Processing record 164 of Set 4 | albany, au
# Processing record 165 of Set 4 | yellowknife, ca
# Processing record 166 of Set 4 | bluff, nz
# Processing record 167 of Set 4 | hobart, au
# Processing record 168 of Set 4 | ushuaia, ar
# Processing record 169 of Set 4 | leh, in
# Processing record 170 of Set 4 | hithadhoo, mv
# Processing record 171 of Set 4 | jamestown, sh
# Processing record 172 of Set 4 | tuktoyaktuk, ca
# Processing record 173 of Set 4 | hithadhoo, mv
# Processing record 174 of Set 4 | avarua, ck
# Processing record 175 of Set 4 | bluff, nz
# Processing record 176 of Set 4 | kodiak, us
# Processing record 177 of Set 4 | ushuaia, ar
# Processing record 178 of Set 4 | kommunisticheskiy, ru
# Processing record 179 of Set 4 | kapaa, us
# Processing record 180 of Set 4 | genhe, cn
# Processing record 181 of Set 4 | atuona, pf
# Processing record 182 of Set 4 | mataura, pf
#    error - one of the data points was not found for this city/country
# Processing record 183 of Set 4 | norsup, vu
# Processing record 184 of Set 4 | havre, us
# Processing record 185 of Set 4 | atuona, pf
# Processing record 186 of Set 4 | rio gallegos, ar
# Processing record 187 of Set 4 | mys shmidta, ru
#    error - one of the data points was not found for this city/country
#
# ------------------------------
#    188 rows processed - 432 remain
# ------------------------------
#
# Processing record 188 of Set 5 | margate, za
# Processing record 189 of Set 5 | busselton, au
# Processing record 190 of Set 5 | fuzhou, cn
# Processing record 191 of Set 5 | ushuaia, ar
# Processing record 192 of Set 5 | pevek, ru
# Processing record 193 of Set 5 | ishigaki, jp
# Processing record 194 of Set 5 | belushya guba, ru
#    error - one of the data points was not found for this city/country
# Processing record 195 of Set 5 | wad madani, sd
# Processing record 196 of Set 5 | rikitea, pf
# Processing record 197 of Set 5 | georgetown, sh
# Processing record 198 of Set 5 | dikson, ru
# Processing record 199 of Set 5 | taolanaro, mg
#    error - one of the data points was not found for this city/country
# Processing record 200 of Set 5 | duminichi, ru
# Processing record 201 of Set 5 | busselton, au
# Processing record 202 of Set 5 | diego de almagro, cl
# Processing record 203 of Set 5 | attawapiskat, ca
#    error - one of the data points was not found for this city/country
# Processing record 204 of Set 5 | tamandare, br
# Processing record 205 of Set 5 | cape town, za
# Processing record 206 of Set 5 | molochnoye, ru
# Processing record 207 of Set 5 | ascension, mx
#    error - one of the data points was not found for this city/country
# Processing record 208 of Set 5 | bambous virieux, mu
# Processing record 209 of Set 5 | bluff, nz
# Processing record 210 of Set 5 | ushuaia, ar
# Processing record 211 of Set 5 | airai, pw
#    error - one of the data points was not found for this city/country
# Processing record 212 of Set 5 | biak, id
# Processing record 213 of Set 5 | ribeira grande, pt
# Processing record 214 of Set 5 | grindavik, is
# Processing record 215 of Set 5 | vostok, ru
# Processing record 216 of Set 5 | roma, au
# Processing record 217 of Set 5 | cabo san lucas, mx
# Processing record 218 of Set 5 | rikitea, pf
# Processing record 219 of Set 5 | rio pardo de minas, br
# Processing record 220 of Set 5 | busselton, au
# Processing record 221 of Set 5 | beroroha, mg
# Processing record 222 of Set 5 | hobart, au
# Processing record 223 of Set 5 | stoyba, ru
#    error - one of the data points was not found for this city/country
# Processing record 224 of Set 5 | kruisfontein, za
# Processing record 225 of Set 5 | mataura, pf
#    error - one of the data points was not found for this city/country
# Processing record 226 of Set 5 | rikitea, pf
# Processing record 227 of Set 5 | sile, tr
# Processing record 228 of Set 5 | kirakira, sb
# Processing record 229 of Set 5 | atuona, pf
# Processing record 230 of Set 5 | punta arenas, cl
# Processing record 231 of Set 5 | lebu, cl
# Processing record 232 of Set 5 | kaitangata, nz
# Processing record 233 of Set 5 | punta arenas, cl
# Processing record 234 of Set 5 | busselton, au
#
# ------------------------------
#    235 rows processed - 385 remain
# ------------------------------
#
# Processing record 235 of Set 6 | asau, tv
#    error - one of the data points was not found for this city/country
# Processing record 236 of Set 6 | ushuaia, ar
# Processing record 237 of Set 6 | amderma, ru
#    error - one of the data points was not found for this city/country
# Processing record 238 of Set 6 | la ronge, ca
# Processing record 239 of Set 6 | samarai, pg
# Processing record 240 of Set 6 | puerto escondido, mx
# Processing record 241 of Set 6 | vila velha, br
# Processing record 242 of Set 6 | belushya guba, ru
#    error - one of the data points was not found for this city/country
# Processing record 243 of Set 6 | cabo san lucas, mx
# Processing record 244 of Set 6 | moree, au
# Processing record 245 of Set 6 | upernavik, gl
# Processing record 246 of Set 6 | fakel, ru
# Processing record 247 of Set 6 | jamestown, sh
# Processing record 248 of Set 6 | khotynets, ru
# Processing record 249 of Set 6 | raudeberg, no
# Processing record 250 of Set 6 | taolanaro, mg
#    error - one of the data points was not found for this city/country
# Processing record 251 of Set 6 | busselton, au
# Processing record 252 of Set 6 | avarua, ck
# Processing record 253 of Set 6 | talavera, pe
# Processing record 254 of Set 6 | east london, za
# Processing record 255 of Set 6 | punta arenas, cl
# Processing record 256 of Set 6 | pokhara, np
# Processing record 257 of Set 6 | kirovskiy, ru
# Processing record 258 of Set 6 | rocha, uy
# Processing record 259 of Set 6 | poum, nc
# Processing record 260 of Set 6 | sidi qasim, ma
#    error - one of the data points was not found for this city/country
# Processing record 261 of Set 6 | dunedin, nz
# Processing record 262 of Set 6 | northam, au
# Processing record 263 of Set 6 | leningradskiy, ru
# Processing record 264 of Set 6 | new norfolk, au
# Processing record 265 of Set 6 | atuona, pf
# Processing record 266 of Set 6 | narsaq, gl
# Processing record 267 of Set 6 | hithadhoo, mv
# Processing record 268 of Set 6 | mahebourg, mu
# Processing record 269 of Set 6 | burica, pa
#    error - one of the data points was not found for this city/country
# Processing record 270 of Set 6 | mashhad, ir
# Processing record 271 of Set 6 | tiarei, pf
# Processing record 272 of Set 6 | busselton, au
# Processing record 273 of Set 6 | taolanaro, mg
#    error - one of the data points was not found for this city/country
# Processing record 274 of Set 6 | belaya gora, ru
# Processing record 275 of Set 6 | verkhnyaya inta, ru
# Processing record 276 of Set 6 | rumphi, mw
# Processing record 277 of Set 6 | port alfred, za
# Processing record 278 of Set 6 | avarua, ck
# Processing record 279 of Set 6 | mgandu, tz
# Processing record 280 of Set 6 | albany, au
# Processing record 281 of Set 6 | busselton, au
#
# ------------------------------
#    282 rows processed - 338 remain
# ------------------------------
#
# Processing record 282 of Set 7 | nizhneyansk, ru
#    error - one of the data points was not found for this city/country
# Processing record 283 of Set 7 | ilulissat, gl
# Processing record 284 of Set 7 | airai, pw
#    error - one of the data points was not found for this city/country
# Processing record 285 of Set 7 | lebu, cl
# Processing record 286 of Set 7 | beringovskiy, ru
# Processing record 287 of Set 7 | saskylakh, ru
# Processing record 288 of Set 7 | port alfred, za
# Processing record 289 of Set 7 | yellowknife, ca
# Processing record 290 of Set 7 | hilo, us
# Processing record 291 of Set 7 | taolanaro, mg
#    error - one of the data points was not found for this city/country
# Processing record 292 of Set 7 | kapaa, us
# Processing record 293 of Set 7 | severo-kurilsk, ru
# Processing record 294 of Set 7 | chifeng, cn
# Processing record 295 of Set 7 | hermanus, za
# Processing record 296 of Set 7 | vaini, to
# Processing record 297 of Set 7 | port alfred, za
# Processing record 298 of Set 7 | longhua, cn
# Processing record 299 of Set 7 | busselton, au
# Processing record 300 of Set 7 | mayo, ca
# Processing record 301 of Set 7 | rikitea, pf
# Processing record 302 of Set 7 | vaini, to
# Processing record 303 of Set 7 | busselton, au
# Processing record 304 of Set 7 | kazalinsk, kz
#    error - one of the data points was not found for this city/country
# Processing record 305 of Set 7 | hobart, au
# Processing record 306 of Set 7 | saint-philippe, re
# Processing record 307 of Set 7 | naze, jp
# Processing record 308 of Set 7 | port alfred, za
# Processing record 309 of Set 7 | bethel, us
# Processing record 310 of Set 7 | bluff, nz
# Processing record 311 of Set 7 | hambantota, lk
# Processing record 312 of Set 7 | atuona, pf
# Processing record 313 of Set 7 | irbil, iq
# Processing record 314 of Set 7 | bhalki, in
# Processing record 315 of Set 7 | millinocket, us
# Processing record 316 of Set 7 | souillac, mu
# Processing record 317 of Set 7 | nikolskoye, ru
# Processing record 318 of Set 7 | marawi, sd
# Processing record 319 of Set 7 | cape town, za
# Processing record 320 of Set 7 | mackay, au
# Processing record 321 of Set 7 | kodiak, us
# Processing record 322 of Set 7 | pemberton, ca
# Processing record 323 of Set 7 | mahebourg, mu
# Processing record 324 of Set 7 | upernavik, gl
# Processing record 325 of Set 7 | arraial do cabo, br
# Processing record 326 of Set 7 | celestun, mx
# Processing record 327 of Set 7 | hithadhoo, mv
# Processing record 328 of Set 7 | sekoma, bw
#
# ------------------------------
#    329 rows processed - 291 remain
# ------------------------------
#
# Processing record 329 of Set 8 | sitka, us
# Processing record 330 of Set 8 | kogota, jp
# Processing record 331 of Set 8 | busselton, au
# Processing record 332 of Set 8 | inverness, ca
# Processing record 333 of Set 8 | saskylakh, ru
# Processing record 334 of Set 8 | vaini, to
# Processing record 335 of Set 8 | illoqqortoormiut, gl
#    error - one of the data points was not found for this city/country
# Processing record 336 of Set 8 | bengkulu, id
# Processing record 337 of Set 8 | cape town, za
# Processing record 338 of Set 8 | flinders, au
# Processing record 339 of Set 8 | kapaa, us
# Processing record 340 of Set 8 | chokurdakh, ru
# Processing record 341 of Set 8 | luena, ao
# Processing record 342 of Set 8 | ushuaia, ar
# Processing record 343 of Set 8 | plettenberg bay, za
# Processing record 344 of Set 8 | georgetown, sh
# Processing record 345 of Set 8 | mitsamiouli, km
# Processing record 346 of Set 8 | norton shores, us
# Processing record 347 of Set 8 | port hedland, au
# Processing record 348 of Set 8 | norman wells, ca
# Processing record 349 of Set 8 | rocha, uy
# Processing record 350 of Set 8 | hlobyne, ua
# Processing record 351 of Set 8 | jamestown, sh
# Processing record 352 of Set 8 | eyl, so
# Processing record 353 of Set 8 | albany, au
# Processing record 354 of Set 8 | tuktoyaktuk, ca
# Processing record 355 of Set 8 | matagami, ca
# Processing record 356 of Set 8 | hermanus, za
# Processing record 357 of Set 8 | nizhneyansk, ru
#    error - one of the data points was not found for this city/country
# Processing record 358 of Set 8 | villacarrillo, es
# Processing record 359 of Set 8 | ancud, cl
# Processing record 360 of Set 8 | ushuaia, ar
# Processing record 361 of Set 8 | ushuaia, ar
# Processing record 362 of Set 8 | isangel, vu
# Processing record 363 of Set 8 | sao filipe, cv
# Processing record 364 of Set 8 | candolim, in
# Processing record 365 of Set 8 | lanigan, ca
# Processing record 366 of Set 8 | aklavik, ca
# Processing record 367 of Set 8 | ossora, ru
# Processing record 368 of Set 8 | mar del plata, ar
# Processing record 369 of Set 8 | katherine, au
# Processing record 370 of Set 8 | hambantota, lk
# Processing record 371 of Set 8 | albany, au
# Processing record 372 of Set 8 | neiafu, to
# Processing record 373 of Set 8 | ribeira grande, pt
# Processing record 374 of Set 8 | luderitz, na
# Processing record 375 of Set 8 | rikitea, pf
#
# ------------------------------
#    376 rows processed - 244 remain
# ------------------------------
#
# Processing record 376 of Set 9 | busselton, au
# Processing record 377 of Set 9 | provideniya, ru
# Processing record 378 of Set 9 | hami, cn
# Processing record 379 of Set 9 | saint george, bm
# Processing record 380 of Set 9 | sur, om
# Processing record 381 of Set 9 | saleaula, ws
#    error - one of the data points was not found for this city/country
# Processing record 382 of Set 9 | hobart, au
# Processing record 383 of Set 9 | lorengau, pg
# Processing record 384 of Set 9 | thompson, ca
# Processing record 385 of Set 9 | havoysund, no
# Processing record 386 of Set 9 | bluff, nz
# Processing record 387 of Set 9 | ushuaia, ar
# Processing record 388 of Set 9 | hobart, au
# Processing record 389 of Set 9 | ushuaia, ar
# Processing record 390 of Set 9 | atuona, pf
# Processing record 391 of Set 9 | abaujszanto, hu
# Processing record 392 of Set 9 | ushuaia, ar
# Processing record 393 of Set 9 | gillette, us
# Processing record 394 of Set 9 | busselton, au
# Processing record 395 of Set 9 | chokurdakh, ru
# Processing record 396 of Set 9 | amderma, ru
#    error - one of the data points was not found for this city/country
# Processing record 397 of Set 9 | xining, cn
# Processing record 398 of Set 9 | boende, cd
# Processing record 399 of Set 9 | laguna, br
# Processing record 400 of Set 9 | airai, pw
#    error - one of the data points was not found for this city/country
# Processing record 401 of Set 9 | tsihombe, mg
#    error - one of the data points was not found for this city/country
# Processing record 402 of Set 9 | attawapiskat, ca
#    error - one of the data points was not found for this city/country
# Processing record 403 of Set 9 | puerto ayora, ec
# Processing record 404 of Set 9 | constitucion, mx
# Processing record 405 of Set 9 | busselton, au
# Processing record 406 of Set 9 | hilo, us
# Processing record 407 of Set 9 | cockburn town, bs
# Processing record 408 of Set 9 | rikitea, pf
# Processing record 409 of Set 9 | albany, au
# Processing record 410 of Set 9 | teguldet, ru
# Processing record 411 of Set 9 | luderitz, na
# Processing record 412 of Set 9 | kahului, us
# Processing record 413 of Set 9 | luanda, ao
# Processing record 414 of Set 9 | waipawa, nz
# Processing record 415 of Set 9 | nizhneyansk, ru
#    error - one of the data points was not found for this city/country
# Processing record 416 of Set 9 | coahuayana, mx
# Processing record 417 of Set 9 | bambous virieux, mu
# Processing record 418 of Set 9 | hobart, au
# Processing record 419 of Set 9 | saint george, bm
# Processing record 420 of Set 9 | mitsamiouli, km
# Processing record 421 of Set 9 | cap malheureux, mu
# Processing record 422 of Set 9 | bredasdorp, za
#
# ------------------------------
#    423 rows processed - 197 remain
# ------------------------------
#
# Processing record 423 of Set 10 | san patricio, mx
# Processing record 424 of Set 10 | kutum, sd
# Processing record 425 of Set 10 | hermanus, za
# Processing record 426 of Set 10 | albany, au
# Processing record 427 of Set 10 | amambai, br
# Processing record 428 of Set 10 | caravelas, br
# Processing record 429 of Set 10 | rikitea, pf
# Processing record 430 of Set 10 | qaanaaq, gl
# Processing record 431 of Set 10 | tuktoyaktuk, ca
# Processing record 432 of Set 10 | rikitea, pf
# Processing record 433 of Set 10 | poum, nc
# Processing record 434 of Set 10 | illoqqortoormiut, gl
#    error - one of the data points was not found for this city/country
# Processing record 435 of Set 10 | padang, id
# Processing record 436 of Set 10 | avarua, ck
# Processing record 437 of Set 10 | guerrero negro, mx
# Processing record 438 of Set 10 | yarim, ye
# Processing record 439 of Set 10 | severo-kurilsk, ru
# Processing record 440 of Set 10 | yellowknife, ca
# Processing record 441 of Set 10 | barrow, us
# Processing record 442 of Set 10 | rikitea, pf
# Processing record 443 of Set 10 | glyadyanskoye, ru
# Processing record 444 of Set 10 | ushuaia, ar
# Processing record 445 of Set 10 | khomeyn, ir
# Processing record 446 of Set 10 | kalambaka, gr
# Processing record 447 of Set 10 | robe, et
# Processing record 448 of Set 10 | lompoc, us
# Processing record 449 of Set 10 | port hedland, au
# Processing record 450 of Set 10 | maldonado, uy
# Processing record 451 of Set 10 | cape town, za
# Processing record 452 of Set 10 | hobart, au
# Processing record 453 of Set 10 | hithadhoo, mv
# Processing record 454 of Set 10 | yerbogachen, ru
# Processing record 455 of Set 10 | atherton, au
# Processing record 456 of Set 10 | dikson, ru
# Processing record 457 of Set 10 | kaitangata, nz
# Processing record 458 of Set 10 | bluff, nz
# Processing record 459 of Set 10 | salalah, om
# Processing record 460 of Set 10 | maningrida, au
# Processing record 461 of Set 10 | longyearbyen, sj
# Processing record 462 of Set 10 | norman wells, ca
# Processing record 463 of Set 10 | busselton, au
# Processing record 464 of Set 10 | amapa, br
# Processing record 465 of Set 10 | pembroke, ca
# Processing record 466 of Set 10 | tiksi, ru
# Processing record 467 of Set 10 | chokurdakh, ru
# Processing record 468 of Set 10 | mys shmidta, ru
#    error - one of the data points was not found for this city/country
# Processing record 469 of Set 10 | longyearbyen, sj
#
# ------------------------------
#    470 rows processed - 150 remain
# ------------------------------
#
# Processing record 470 of Set 11 | mys shmidta, ru
#    error - one of the data points was not found for this city/country
# Processing record 471 of Set 11 | dingle, ie
# Processing record 472 of Set 11 | hithadhoo, mv
# Processing record 473 of Set 11 | nyborg, dk
# Processing record 474 of Set 11 | punta arenas, cl
# Processing record 475 of Set 11 | belushya guba, ru
#    error - one of the data points was not found for this city/country
# Processing record 476 of Set 11 | hermanus, za
# Processing record 477 of Set 11 | ancud, cl
# Processing record 478 of Set 11 | kodiak, us
# Processing record 479 of Set 11 | georgetown, sh
# Processing record 480 of Set 11 | dikson, ru
# Processing record 481 of Set 11 | khatanga, ru
# Processing record 482 of Set 11 | cabo san lucas, mx
# Processing record 483 of Set 11 | vaitape, pf
# Processing record 484 of Set 11 | inuvik, ca
# Processing record 485 of Set 11 | busselton, au
# Processing record 486 of Set 11 | walvis bay, na
# Processing record 487 of Set 11 | aloleng, ph
# Processing record 488 of Set 11 | new norfolk, au
# Processing record 489 of Set 11 | bundaberg, au
# Processing record 490 of Set 11 | hermanus, za
# Processing record 491 of Set 11 | butaritari, ki
# Processing record 492 of Set 11 | nizhniy kuranakh, ru
# Processing record 493 of Set 11 | nanortalik, gl
# Processing record 494 of Set 11 | mataura, pf
#    error - one of the data points was not found for this city/country
# Processing record 495 of Set 11 | kapaa, us
# Processing record 496 of Set 11 | ushuaia, ar
# Processing record 497 of Set 11 | gat, ly
#    error - one of the data points was not found for this city/country
# Processing record 498 of Set 11 | mys shmidta, ru
#    error - one of the data points was not found for this city/country
# Processing record 499 of Set 11 | bengkulu, id
# Processing record 500 of Set 11 | nikolskoye, ru
# Processing record 501 of Set 11 | kaitangata, nz
# Processing record 502 of Set 11 | pevek, ru
# Processing record 503 of Set 11 | tuktoyaktuk, ca
# Processing record 504 of Set 11 | riyadh, sa
# Processing record 505 of Set 11 | atuona, pf
# Processing record 506 of Set 11 | bluff, nz
# Processing record 507 of Set 11 | flinders, au
# Processing record 508 of Set 11 | hithadhoo, mv
# Processing record 509 of Set 11 | halifax, ca
# Processing record 510 of Set 11 | busselton, au
# Processing record 511 of Set 11 | sao jose dos pinhais, br
# Processing record 512 of Set 11 | altay, cn
# Processing record 513 of Set 11 | aklavik, ca
# Processing record 514 of Set 11 | barrow, us
# Processing record 515 of Set 11 | atar, mr
# Processing record 516 of Set 11 | severo-kurilsk, ru
#
# ------------------------------
#    517 rows processed - 103 remain
# ------------------------------
#
# Processing record 517 of Set 12 | castro, cl
# Processing record 518 of Set 12 | taolanaro, mg
#    error - one of the data points was not found for this city/country
# Processing record 519 of Set 12 | tuktoyaktuk, ca
# Processing record 520 of Set 12 | vaitupu, wf
#    error - one of the data points was not found for this city/country
# Processing record 521 of Set 12 | ballina, au
# Processing record 522 of Set 12 | camacha, pt
# Processing record 523 of Set 12 | ilulissat, gl
# Processing record 524 of Set 12 | thompson, ca
# Processing record 525 of Set 12 | taolanaro, mg
#    error - one of the data points was not found for this city/country
# Processing record 526 of Set 12 | komsomolskiy, ru
# Processing record 527 of Set 12 | port alfred, za
# Processing record 528 of Set 12 | chuy, uy
# Processing record 529 of Set 12 | den helder, nl
# Processing record 530 of Set 12 | kantilo, in
# Processing record 531 of Set 12 | vavozh, ru
# Processing record 532 of Set 12 | tineo, es
# Processing record 533 of Set 12 | atuona, pf
# Processing record 534 of Set 12 | new norfolk, au
# Processing record 535 of Set 12 | busselton, au
# Processing record 536 of Set 12 | narsaq, gl
# Processing record 537 of Set 12 | mataura, pf
#    error - one of the data points was not found for this city/country
# Processing record 538 of Set 12 | bengkulu, id
# Processing record 539 of Set 12 | karratha, au
# Processing record 540 of Set 12 | fortuna, us
# Processing record 541 of Set 12 | kapaa, us
# Processing record 542 of Set 12 | hambantota, lk
# Processing record 543 of Set 12 | ushuaia, ar
# Processing record 544 of Set 12 | atuona, pf
# Processing record 545 of Set 12 | bacungan, ph
# Processing record 546 of Set 12 | karratha, au
# Processing record 547 of Set 12 | cape town, za
# Processing record 548 of Set 12 | cape town, za
# Processing record 549 of Set 12 | yangmei, tw
# Processing record 550 of Set 12 | taoudenni, ml
# Processing record 551 of Set 12 | esperance, au
# Processing record 552 of Set 12 | khovu-aksy, ru
# Processing record 553 of Set 12 | alta floresta, br
# Processing record 554 of Set 12 | tiksi, ru
# Processing record 555 of Set 12 | port blair, in
# Processing record 556 of Set 12 | fortuna, us
# Processing record 557 of Set 12 | kazalinsk, kz
#    error - one of the data points was not found for this city/country
# Processing record 558 of Set 12 | taolanaro, mg
#    error - one of the data points was not found for this city/country
# Processing record 559 of Set 12 | itoman, jp
# Processing record 560 of Set 12 | isangel, vu
# Processing record 561 of Set 12 | hermanus, za
# Processing record 562 of Set 12 | doha, qa
# Processing record 563 of Set 12 | laguna, br
#
# ------------------------------
#    564 rows processed - 56 remain
# ------------------------------
#
# Processing record 564 of Set 13 | puerto ayora, ec
# Processing record 565 of Set 13 | samusu, ws
#    error - one of the data points was not found for this city/country
# Processing record 566 of Set 13 | airai, pw
#    error - one of the data points was not found for this city/country
# Processing record 567 of Set 13 | russell, nz
# Processing record 568 of Set 13 | jiuquan, cn
# Processing record 569 of Set 13 | jamestown, sh
# Processing record 570 of Set 13 | kaeo, nz
# Processing record 571 of Set 13 | rikitea, pf
# Processing record 572 of Set 13 | ushuaia, ar
# Processing record 573 of Set 13 | tasiilaq, gl
# Processing record 574 of Set 13 | port alfred, za
# Processing record 575 of Set 13 | butaritari, ki
# Processing record 576 of Set 13 | bredasdorp, za
# Processing record 577 of Set 13 | grand river south east, mu
#    error - one of the data points was not found for this city/country
# Processing record 578 of Set 13 | busselton, au
# Processing record 579 of Set 13 | arraial do cabo, br
# Processing record 580 of Set 13 | sao filipe, cv
# Processing record 581 of Set 13 | mana, gf
# Processing record 582 of Set 13 | rungata, ki
#    error - one of the data points was not found for this city/country
# Processing record 583 of Set 13 | yellowknife, ca
# Processing record 584 of Set 13 | tasiilaq, gl
# Processing record 585 of Set 13 | ban nahin, la
# Processing record 586 of Set 13 | megion, ru
# Processing record 587 of Set 13 | nikolskoye, ru
# Processing record 588 of Set 13 | vao, nc
# Processing record 589 of Set 13 | ushuaia, ar
# Processing record 590 of Set 13 | codrington, ag
#    error - one of the data points was not found for this city/country
# Processing record 591 of Set 13 | vestmannaeyjar, is
# Processing record 592 of Set 13 | imbituba, br
# Processing record 593 of Set 13 | hilo, us
# Processing record 594 of Set 13 | torbay, ca
# Processing record 595 of Set 13 | iqaluit, ca
# Processing record 596 of Set 13 | san ramon de la nueva oran, ar
# Processing record 597 of Set 13 | turtkul, uz
#    error - one of the data points was not found for this city/country
# Processing record 598 of Set 13 | bredasdorp, za
# Processing record 599 of Set 13 | mys shmidta, ru
#    error - one of the data points was not found for this city/country
# Processing record 600 of Set 13 | guerrero negro, mx
# Processing record 601 of Set 13 | lompoc, us
# Processing record 602 of Set 13 | victoria, sc
# Processing record 603 of Set 13 | mandalgovi, mn
# Processing record 604 of Set 13 | belyy yar, ru
# Processing record 605 of Set 13 | rikitea, pf
# Processing record 606 of Set 13 | conde, br
# Processing record 607 of Set 13 | katsuura, jp
# Processing record 608 of Set 13 | guerrero negro, mx
# Processing record 609 of Set 13 | mezen, ru
# Processing record 610 of Set 13 | palmer, us
#
# ------------------------------
#    611 rows processed - 9 remain
# ------------------------------
#
# Processing record 611 of Set 14 | saskylakh, ru
# Processing record 612 of Set 14 | nanchang, cn
# Processing record 613 of Set 14 | missoula, us
# Processing record 614 of Set 14 | barrow, us
# Processing record 615 of Set 14 | nalut, ly
# Processing record 616 of Set 14 | butaritari, ki
# Processing record 617 of Set 14 | saskylakh, ru
# Processing record 618 of Set 14 | cherskiy, ru
# Processing record 619 of Set 14 | kulhudhuffushi, mv
# Processing record 620 of Set 14 | port alfred, za

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#print(weather_json)
#print(weather.url)
#print(json.dumps(weather_json, indent=4, sort_keys=True))

curr_rows = len(df)
print(f'There are {curr_rows} coordinates in the dataframe')
print('... dropping rows that do not have weather data...')
df = df.dropna(how="any")
curr_rows = len(df)
print(f'After dropna(), there are now {curr_rows} coordinates in the dataframe')

df.to_csv (f'{output_folder}\RawData.csv', index = None, header=True) 
df.head()
# Out:
# There are 620 coordinates in the dataframe
# ... dropping rows that do not have weather data...
# After dropna(), there are now 552 coordinates in the dataframe
#     Latitude   Longitude          City Country        Date Cloudiness  \
# 1 -70.151047   26.986246  kruisfontein      za  2020-01-23          4
# 2 -75.898007    5.550883      hermanus      za  2020-01-23          0
# 3 -82.451657  -60.138620       ushuaia      ar  2020-01-23         75
# 4  83.501309  -56.554683     upernavik      gl  2020-01-23         44
# 6 -29.975359 -129.818902       rikitea      pf  2020-01-23          0
#
#   Humidity Max Temp Wind Speed
# 1       86    63.84      13.42
# 2       80       70      11.99
# 3       71       50      24.16
# 4       59    -5.66       9.15
# 6       77     79.5      16.91

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
## Convert to floats
x_values = df['Latitude'].astype('float')
y_values = df['Max Temp'].astype('float')

# Plot scatter plot
plt.scatter(x_values, y_values)

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs. Max Temp ({date.today()})')
plt.grid()

# Show plot
plt.savefig(f'{output_folder}\plot_lat_vs_max_temp.png')
plt.show()

print("The relationship a city's latitude has with it's maximum temperature (F)")
print('The skew towards the +20 and higher latitudes may be explained by lower hemisphere countries in Africa, Java, etc')
# Out:
# The relationship a city's latitude has with it's maximum temperature (F)
# The skew towards the +20 and higher latitudes may be explained by lower hemisphere countries in Africa, Java, etc

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
## Convert to floats
x_values = df['Latitude'].astype('float')
y_values = df['Humidity'].astype('float')

# Plot scatter plot
plt.scatter(x_values, y_values)

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs. Humidity ({date.today()})')
plt.grid()

# Show plot
plt.savefig(f'{output_folder}\plot_lat_vs_humidity.png')
plt.show()

print("The relationship a city's latitude has with it's humidity")
print('No clear and obvious relationships exist')
# Out:
# The relationship a city's latitude has with it's humidity
# No clear and obvious relationships exist

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
## Convert to floats
x_values = df['Latitude'].astype('float')
y_values = df['Cloudiness'].astype('float')

# Plot scatter plot
plt.scatter(x_values, y_values)

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs. Cloudiness ({date.today()})')
plt.grid()

# Show plot
plt.savefig(f'{output_folder}\plot_lat_vs_clouds.png')
plt.show()

print("The relationship a city's latitude has with it's cloudiness")
print('No clear and obvious relationships exist. Perhaps a measurement error but seems some clustering around 77% but no explanation as to why')
# Out:
# The relationship a city's latitude has with it's cloudiness
# No clear and obvious relationships exist. Perhaps a measurement error but seems some clustering around 77% but no explanation as to why

# %% [markdown]
# #### Latitude vs. Wind Speed plot

# %%
## Convert to floats
x_values = df['Latitude'].astype('float')
y_values = df['Wind Speed'].astype('float')

# Plot scatter plot
plt.scatter(x_values, y_values)

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs. Wind Speed ({date.today()})')
plt.grid()

# Show plot
plt.savefig(f'{output_folder}\plot_lat_vs_wind.png')
plt.show()

print("The relationship a city's latitude has with it's wind speed")
print('Pretty flat - perhaps an outlier or two as well')
# Out:
# The relationship a city's latitude has with it's wind speed
# Pretty flat - perhaps an outlier or two as well

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

### BONUS 

def lin_line(x_values, y_values, plt, x_thing, y_thing):

    # Run linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Plot regression line
    plt.plot(
        x_values, 
        regress_values,
        "r-", 
        marker='o',
        markerfacecolor='blue',
        markeredgecolor='black'
    )
    
    plt.annotate(line_eq, (6,10), fontsize=15, color="red")

    # Print r square value
    print(f"R squared: {rvalue}")

    if rvalue <= -0.9:
        print(f'   - N.B. R-squared is <= -0.9 showing a definite relationship b/w {x_thing} and {y_thing}')
    elif rvalue <= -0.5:
        print(f'   - N.B. R-squared is <= -0.5 indicating there is a decent relationship b/w {x_thing} and {y_thing}')
    elif rvalue <= 0.2:
        print(f'   - N.B. R-squared is > -0.5 but < 0.2 indicating little to no definite relationship b/w {x_thing} and {y_thing}')
    elif rvalue >= 0.9:
        print(f'   - N.B. R-squared is >= 0.9 indicating there is a definite relationship b/w {x_thing} and {y_thing}')
    elif rvalue >= 0.5:
        print(f'   - N.B. R-squared is >= 0.5 indicating there is a decent relationship b/w {x_thing} and {y_thing}')
    else: 
        print(f'   - N.B. R-squared is >= 0.2 but < 0.5 indicating little to no definite relationship  b/w {x_thing} and {y_thing}')

# %%
# Create Northern and Southern Hemisphere DataFrames
the_union = df[(df["Latitude"] >= 0)]
the_confederates = df[(df["Latitude"] < 0)]

print(f'There are {len(the_union)} rows in the Northern hemisphere')
print(f'Ya\'ll, there are {len(the_confederates)} rows in the Southern, I said Southern, hemisphere')
# Out:
# There are 254 rows in the Northern hemisphere
# Ya'll, there are 298 rows in the Southern, I said Southern, hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Convert to floats
x_values = the_union['Latitude'].astype('float')
y_values = the_union['Max Temp'].astype('float')

# Plot scatter plot
plt.scatter(x_values, y_values)

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'Northern Hemisphere: Latitude vs. Max Temp ({date.today()})')

lin_line(x_values, y_values, plt, 'Latitude', 'Max Temp(F)')

# Show plot
plt.savefig(f'{output_folder}\plot_lat_vs_max_temp-linear-north.png')
plt.show()

print("The relationship a city's latitude has with it's maximum temperature (F)")
# Out:
# R squared: -0.8688344932261053
#    - N.B. R-squared is <= -0.5 indicating there is a decent relationship b/w Latitude and Max Temp(F)
# The relationship a city's latitude has with it's maximum temperature (F)

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Convert to floats
x_values = the_confederates['Latitude'].astype('float')
y_values = the_confederates['Max Temp'].astype('float')

# Plot scatter plot
plt.scatter(x_values, y_values)

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'Southern Hemisphere: Latitude vs. Max Temp ({date.today()})')

lin_line(x_values, y_values, plt, 'Latitude', 'Max Temp(F)')

# Show plot
plt.savefig(f'{output_folder}\plot_lat_vs_max_temp-linear-south.png')
plt.show()

print("The relationship a city's latitude has with it's maximum temperature (F)")
# Out:
# R squared: 0.6531697172047972
#    - N.B. R-squared is >= 0.5 indicating there is a decent relationship b/w Latitude and Max Temp(F)
# The relationship a city's latitude has with it's maximum temperature (F)

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Convert to floats
x_values = the_union['Latitude'].astype('float')
y_values = the_union['Humidity'].astype('float')

# Plot scatter plot
plt.scatter(x_values, y_values)

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Northern Hemisphere: Latitude vs. Humidity ({date.today()})')
plt.grid()

lin_line(x_values, y_values, plt, 'Latitude', 'Humidity')

# Show plot
plt.savefig(f'{output_folder}\plot_lat_vs_humid-linear-north.png')
plt.show()

print("The relationship a city's latitude has with it's humidity(%)")
# Out:
# R squared: 0.28252790207308104
#    - N.B. R-squared is >= 0.2 but < 0.5 indicating little to no definite relationship  b/w Latitude and Humidity
# The relationship a city's latitude has with it's humidity(%)

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Convert to floats
x_values = the_confederates['Latitude'].astype('float')
y_values = the_confederates['Humidity'].astype('float')

# Plot scatter plot
plt.scatter(x_values, y_values)

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Southern Hemisphere: Latitude vs. Humidity ({date.today()})')
plt.grid()

lin_line(x_values, y_values, plt, 'Latitude', 'Humidity')

# Show plot
plt.savefig(f'{output_folder}\plot_lat_vs_humid-linear-south.png')
plt.show()

print("The relationship a city's latitude has with it's humidity(%)")
# Out:
# R squared: 0.2711666556119306
#    - N.B. R-squared is >= 0.2 but < 0.5 indicating little to no definite relationship  b/w Latitude and Humidity
# The relationship a city's latitude has with it's humidity(%)

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Convert to floats
x_values = the_union['Latitude'].astype('float')
y_values = the_union['Cloudiness'].astype('float')

# Plot scatter plot
plt.scatter(x_values, y_values)

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'Northern Hemisphere: Latitude vs. Cloudiness ({date.today()})')
plt.grid()
lin_line(x_values, y_values, plt, 'Latitude', 'Cloudiness')

# Show plot
plt.savefig(f'{output_folder}\plot_lat_vs_cloud-linear-north.png')
plt.show()

print("The relationship a city's latitude has with it's cloudiness(%)")
# Out:
# R squared: 0.15163265571380147
#    - N.B. R-squared is > -0.5 but < 0.2 indicating little to no definite relationship b/w Latitude and Cloudiness
# The relationship a city's latitude has with it's cloudiness(%)

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Convert to floats
x_values = the_confederates['Latitude'].astype('float')
y_values = the_confederates['Cloudiness'].astype('float')

# Plot scatter plot
plt.scatter(x_values, y_values)

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'Southern Hemisphere: Latitude vs. Cloudiness ({date.today()})')
plt.grid()

lin_line(x_values, y_values, plt, 'Latitude', 'Cloudiness')

# Show plot
plt.savefig(f'{output_folder}\plot_lat_vs_cloud-linear-south.png')
plt.show()

print("The relationship a city's latitude has with it's cloudiness(%)")
# Out:
# R squared: 0.10758410050984284
#    - N.B. R-squared is > -0.5 but < 0.2 indicating little to no definite relationship b/w Latitude and Cloudiness
# The relationship a city's latitude has with it's cloudiness(%)

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Convert to floats
x_values = the_union['Latitude'].astype('float')
y_values = the_union['Wind Speed'].astype('float')

# Plot scatter plot
plt.scatter(x_values, y_values)

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Northern Hemisphere: Latitude vs. Wind Speed ({date.today()})')
plt.grid()
lin_line(x_values, y_values, plt, 'Latitude', 'Wind Speed')

# Show plot
plt.savefig(f'{output_folder}\plot_lat_vs_wind-linear-north.png')
plt.show()

print("The relationship a city's latitude has with it's wind speed")
# Out:
# R squared: 0.17316481001208175
#    - N.B. R-squared is > -0.5 but < 0.2 indicating little to no definite relationship b/w Latitude and Wind Speed
# The relationship a city's latitude has with it's wind speed

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Convert to floats
x_values = the_confederates['Latitude'].astype('float')
y_values = the_confederates['Wind Speed'].astype('float')

# Plot scatter plot
plt.scatter(x_values, y_values)

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Southern Hemisphere: Latitude vs. Wind Speed ({date.today()})')
plt.grid()
lin_line(x_values, y_values, plt, 'Latitude', 'Wind Speed')

# Show plot
plt.savefig(f'{output_folder}\plot_lat_vs_wind-linear-south.png')
plt.show()

print("The relationship a city's latitude has with it's wind speed")
# Out:
# R squared: -0.25102010816133297
#    - N.B. R-squared is > -0.5 but < 0.2 indicating little to no definite relationship b/w Latitude and Wind Speed
# The relationship a city's latitude has with it's wind speed
